# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./input/techgroups.xlsx')

# %%
df
# Out:
#        Latitude  Longitude                city        id  \
# 0     50.937810   4.040952               Aalst  20052756
# 1     50.985996   4.836522            Aarschot  14447362
# 2     46.196821   6.099552                Aire  19109708
# 3     45.899247   6.129384              Annecy  12981332
# 4     45.899247   6.129384              Annecy  16614282
# 5     43.580418   7.125102             Antibes  20153479
# 6     43.580418   7.125102             Antibes  19747665
# 7     43.580418   7.125102             Antibes  18895222
# 8     43.580418   7.125102             Antibes  19499730
# 9     43.580418   7.125102             Antibes  18500781
# 10    43.580418   7.125102             Antibes  18803699
# 11    43.580418   7.125102             Antibes  18754566
# 12    43.580418   7.125102             Antibes   1736475
# 13    48.914155   2.285369  Asnières-sur-Seine   9038552
# 14    48.914155   2.285369  Asnières-sur-Seine   9038552
# ...

# %%
df['created']=pd.to_datetime(df.created)

# %%
df.dtypes
# Out:
# Latitude            float64
# Longitude           float64
# city                 object
# id                    int64
# name                 object
# members               int64
# rating               object
# created      datetime64[ns]
# dtype: object

# %%
df.to_excel('./input/techgroups.xlsx')

# %%
df = pd.read_excel('./input/techgroups.xlsx')

# %%
df
# Out:
#        Latitude  Longitude                city        id  \
# 0     50.937810   4.040952               Aalst  20052756
# 1     50.985996   4.836522            Aarschot  14447362
# 2     46.196821   6.099552                Aire  19109708
# 3     45.899247   6.129384              Annecy  12981332
# 4     45.899247   6.129384              Annecy  16614282
# 5     43.580418   7.125102             Antibes  20153479
# 6     43.580418   7.125102             Antibes  19747665
# 7     43.580418   7.125102             Antibes  18895222
# 8     43.580418   7.125102             Antibes  19499730
# 9     43.580418   7.125102             Antibes  18500781
# 10    43.580418   7.125102             Antibes  18803699
# 11    43.580418   7.125102             Antibes  18754566
# 12    43.580418   7.125102             Antibes   1736475
# 13    48.914155   2.285369  Asnières-sur-Seine   9038552
# 14    48.914155   2.285369  Asnières-sur-Seine   9038552
# ...

# %%
df.dtypes
# Out:
# Latitude            float64
# Longitude           float64
# city                 object
# id                    int64
# name                 object
# members               int64
# rating               object
# created      datetime64[ns]
# dtype: object

# %%
df.to_csv('./input/techgroups.csv')

# %%
df
# Out:
#        Latitude  Longitude                city        id  \
# 0     50.937810   4.040952               Aalst  20052756
# 1     50.985996   4.836522            Aarschot  14447362
# 2     46.196821   6.099552                Aire  19109708
# 3     45.899247   6.129384              Annecy  12981332
# 4     45.899247   6.129384              Annecy  16614282
# 5     43.580418   7.125102             Antibes  20153479
# 6     43.580418   7.125102             Antibes  19747665
# 7     43.580418   7.125102             Antibes  18895222
# 8     43.580418   7.125102             Antibes  19499730
# 9     43.580418   7.125102             Antibes  18500781
# 10    43.580418   7.125102             Antibes  18803699
# 11    43.580418   7.125102             Antibes  18754566
# 12    43.580418   7.125102             Antibes   1736475
# 13    48.914155   2.285369  Asnières-sur-Seine   9038552
# 14    48.914155   2.285369  Asnières-sur-Seine   9038552
# ...

# %%
df.dtypes
# Out:
# Latitude            float64
# Longitude           float64
# city                 object
# id                    int64
# name                 object
# members               int64
# rating               object
# created      datetime64[ns]
# dtype: object

# %%
df['year'], df['month']=df['created'].dt.year, df['created'].dt.month

# %%
df
# Out:
#        Latitude  Longitude                city        id  \
# 0     50.937810   4.040952               Aalst  20052756
# 1     50.985996   4.836522            Aarschot  14447362
# 2     46.196821   6.099552                Aire  19109708
# 3     45.899247   6.129384              Annecy  12981332
# 4     45.899247   6.129384              Annecy  16614282
# 5     43.580418   7.125102             Antibes  20153479
# 6     43.580418   7.125102             Antibes  19747665
# 7     43.580418   7.125102             Antibes  18895222
# 8     43.580418   7.125102             Antibes  19499730
# 9     43.580418   7.125102             Antibes  18500781
# 10    43.580418   7.125102             Antibes  18803699
# 11    43.580418   7.125102             Antibes  18754566
# 12    43.580418   7.125102             Antibes   1736475
# 13    48.914155   2.285369  Asnières-sur-Seine   9038552
# 14    48.914155   2.285369  Asnières-sur-Seine   9038552
# ...

# %%
df.to_csv('./input/techgroups.csv')
